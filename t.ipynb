# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
d = {
    "Alex": [30, 40],
    "Brian": [100,40],
    "Cindy": [0, 80],
    "Daniel": [50, 90],
    "Emma": [100,20 ],
    "Fred": [0, 20]
}

# %%
df = pd.DataFrame(d)

# %%
df
# Out:
#    Alex  Brian  Cindy  Daniel  Emma  Fred  turn
# 0    30    100      0      50   100     0     0
# 1    40     40     80      90    20    20     1

# %%
plt.plot(df)
